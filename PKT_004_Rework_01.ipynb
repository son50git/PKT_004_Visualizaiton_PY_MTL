# %% [markdown]
# <a href="https://colab.research.google.com/github/son50git/PKT_004_Visualizaiton_PY_MTL/blob/master/PKT_004_Rework_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = [-3, 5, 7]
y = [10, 2, 5]

plt.figure(figsize=(15,3))
plt.plot(x, y)
plt.xlim(0, 10)
plt.ylim(-3, 8)
plt.xlabel('X Axis')
plt.ylabel('Y axis')
plt.title('Line Plot')
plt.suptitle('Figure Title', size=20, x=0.51, y=1.03) # default x=0.50 y=0.98
# Out:
# Text(0.51, 1.03, 'Figure Title')

# %%
fig, ax = plt.subplots(figsize=(15,3))
ax.plot(x, y)
ax.set_xlim(0, 10)
ax.set_ylim(-3, 8)
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_title('Line Plot')
fig.suptitle('Figure Title', size=20, x=0.51, y=1.03)  # super title at fig level
# Out:
# Text(0.51, 1.03, 'Figure Title')

# %%
fig, ax = plt.subplots(nrows=1, ncols=1)

# %%
print(type(fig)) 
print(type(ax))
# Out:
# <class 'matplotlib.figure.Figure'>
# <class 'matplotlib.axes._subplots.AxesSubplot'>
# True

# %%
plot_objects = plt.subplots(nrows=1, ncols=1)
print(type(plot_objects)) 
print(plot_objects)
# Out:
# <class 'tuple'>
# (<Figure size 432x288 with 1 Axes>, <matplotlib.axes._subplots.AxesSubplot object at 0x7f2d4649b860>)

# %%
plot_objects = plt.subplots(nrows=1, ncols=2)
print(plot_objects[0]) 
print(type(plot_objects))
print(plot_objects[1]) 
print(type(plot_objects[1]))
# Out:
# Figure(432x288)
# <class 'tuple'>
# [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2d46bae710>
#  <matplotlib.axes._subplots.AxesSubplot object at 0x7f2d46e23898>]
# <class 'numpy.ndarray'>

# %%
plot_objects = plt.subplots(nrows=2, ncols=1)
print(plot_objects[0]) 
print(type(plot_objects))
print(plot_objects[1]) 
print(type(plot_objects[1]))
# Out:
# Figure(432x288)
# <class 'tuple'>
# [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2d46757be0>
#  <matplotlib.axes._subplots.AxesSubplot object at 0x7f2d4683c4a8>]
# <class 'numpy.ndarray'>

# %%
plot_objects = plt.subplots(nrows=2, ncols=2)
print(plot_objects[0]) 
print(type(plot_objects))
print(plot_objects[1]) 
print(type(plot_objects[1]))
# Out:
# Figure(432x288)
# <class 'tuple'>
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2d471f9eb8>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x7f2d47a617f0>]
#  [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2d46327b38>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x7f2d46aa53c8>]]
# <class 'numpy.ndarray'>

# %%
fig = plot_objects[0]
print(type(fig)) 
ax = plot_objects[1]
print(type(ax))
# Out:
# <class 'matplotlib.figure.Figure'>
# <class 'numpy.ndarray'>

# %%
fig

# %%
fig.get_size_inches()
# Out:
# array([6., 4.])

# %%
fig.set_size_inches(14, 4)
fig

# %%
plot_objects = plt.subplots(nrows=1, ncols=1)

# %%
fig = plot_objects[0]
ax = plot_objects[1]
print(ax)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
fig.axes

# %%
fig.axes[0]

# %%
fig.axes[0] is ax
# Out:
# True

# %%
fig.set_size_inches(14, 4)

fig.set_facecolor('.9')
ax.set_facecolor('.7')
fig

# %%
ax_children = ax.get_children()
ax_children
# Out:
# [<matplotlib.spines.Spine at 0x7f2d46731630>,
#  <matplotlib.spines.Spine at 0x7f2d46a79208>,
#  <matplotlib.spines.Spine at 0x7f2d46a792e8>,
#  <matplotlib.spines.Spine at 0x7f2d46da7ac8>,
#  <matplotlib.axis.XAxis at 0x7f2d46731cf8>,
#  <matplotlib.axis.YAxis at 0x7f2d46afe390>,
#  Text(0.5, 1.0, ''),
#  Text(0.0, 1.0, ''),
#  Text(1.0, 1.0, ''),
#  <matplotlib.patches.Rectangle at 0x7f2d46d4b278>]

# %%
spines = ax.spines
spines
# Out:
# OrderedDict([('left', <matplotlib.spines.Spine at 0x7f2d46731630>),
#              ('right', <matplotlib.spines.Spine at 0x7f2d46a79208>),
#              ('bottom', <matplotlib.spines.Spine at 0x7f2d46a792e8>),
#              ('top', <matplotlib.spines.Spine at 0x7f2d46da7ac8>)])

# %%
spine_left = spines['left']
spine_left.set_position(('outward', -100))
spine_left.set_linewidth(5)

spine_bottom = spines['bottom']
spine_bottom.set_visible(False)
fig

# %%
ax.xaxis.grid(True, which='major', linewidth=2, color='black', linestyle='--')
ax.xaxis.set_ticks([.2, .4, .55, .93])
ax.xaxis.set_label_text('X Axis', family='Verdana', fontsize=15)

ax.set_ylabel('Y Axis', family='Calibri', fontsize=20)
ax.set_yticks([.1, .9])
ax.set_yticklabels(['point 1', 'point 9'], rotation=45)
fig

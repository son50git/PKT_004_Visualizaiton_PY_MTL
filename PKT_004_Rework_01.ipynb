# %% [markdown]
# <a href="https://colab.research.google.com/github/son50git/PKT_004_Visualizaiton_PY_MTL/blob/master/PKT_004_Rework_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = [-3, 5, 7]
y = [10, 2, 5]

plt.figure(figsize=(15,3))  # stateful approach
plt.plot(x, y)
plt.xlim(0, 10)
plt.ylim(-3, 8)
plt.xlabel('X Axis')
plt.ylabel('Y axis')
plt.title('Line Plot')
plt.suptitle('Figure Title', size=20, x=0.51, y=1.03) # default x=0.50 y=0.98
# Out:
# Text(0.51, 1.03, 'Figure Title')

# %%
fig, ax = plt.subplots(figsize=(15,3))  # stateless approach
ax.plot(x, y)
ax.set_xlim(0, 10)
ax.set_ylim(-3, 8)
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_title('Line Plot')
fig.suptitle('Figure Title', size=20, x=0.51, y=1.03)  # super title at fig level
# Out:
# Text(0.51, 1.03, 'Figure Title')

# %%
fig, ax = plt.subplots(nrows=1, ncols=1)

# %%
print(type(fig)) 
print(type(ax))
# Out:
# <class 'matplotlib.figure.Figure'>
# <class 'matplotlib.axes._subplots.AxesSubplot'>

# %%
plot_objects = plt.subplots(nrows=1, ncols=1)
print(type(plot_objects)) 
print(plot_objects)
# Out:
# <class 'tuple'>
# (<Figure size 432x288 with 1 Axes>, <matplotlib.axes._subplots.AxesSubplot object at 0x7fbf55f90a90>)

# %%
plot_objects = plt.subplots(nrows=1, ncols=2)
print(plot_objects[0]) 
print(type(plot_objects))
print(plot_objects[1]) 
print(type(plot_objects[1]))
# Out:
# Figure(432x288)
# <class 'tuple'>
# ...
# <class 'numpy.ndarray'>

# %%
plot_objects = plt.subplots(nrows=2, ncols=1)
print(plot_objects[0]) 
print(type(plot_objects))
print(plot_objects[1]) 
print(type(plot_objects[1]))
# Out:
# Figure(432x288)
# <class 'tuple'>
# ...
# <class 'numpy.ndarray'>

# %%
plot_objects = plt.subplots(nrows=2, ncols=2)
print(plot_objects[0]) 
print(type(plot_objects))
print(plot_objects[1]) 
print(type(plot_objects[1]))
# Out:
# Figure(432x288)
# <class 'tuple'>
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x7fbf55e071d0>
# ...
# <class 'numpy.ndarray'>

# %%
fig = plot_objects[0]
print(type(fig)) 
ax = plot_objects[1]
print(type(ax))
# Out:
# <class 'matplotlib.figure.Figure'>
# <class 'numpy.ndarray'>

# %%
fig

# %%
fig.get_size_inches()
# Out:
# array([6., 4.])

# %%
fig.set_size_inches(14, 4)
fig

# %%
plot_objects = plt.subplots(nrows=1, ncols=1)

# %%
fig = plot_objects[0]
ax = plot_objects[1]
print(ax)
print(plot_objects)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# (<Figure size 432x288 with 1 Axes>, <matplotlib.axes._subplots.AxesSubplot object at 0x7fbf55d315f8>)

# %%
fig.axes

# %%
fig.axes[0]

# %%
fig.axes[0] is ax
# Out:
# True

# %%
fig.set_size_inches(14, 4)

fig.set_facecolor('.9')
ax.set_facecolor('.7')
fig

# %%
ax_children = ax.get_children()  # spines represent the data boundaries with four physical lines
ax_children
# Out:
# ...
#  Text(0.5, 1.0, ''),
#  Text(0.0, 1.0, ''),
#  Text(1.0, 1.0, ''),
# ...

# %%
tmp = ax.axis
tmp
# Out:
# <bound method _AxesBase.axis of <matplotlib.axes._subplots.AxesSubplot object at 0x7fbf55d315f8>>

# %%
spines = ax.spines
spines
# Out:
# OrderedDict([('left', <matplotlib.spines.Spine at 0x7fbf55cd1668>),
#              ('right', <matplotlib.spines.Spine at 0x7fbf55cd1160>),
#              ('bottom', <matplotlib.spines.Spine at 0x7fbf55cd1b00>),
#              ('top', <matplotlib.spines.Spine at 0x7fbf55cd1b70>)])

# %%
tmp = ax.patches
tmp
# Out:
# []

# %%
spine_left = spines['left']
spine_left

# %%
spine_left = spines['left']
spine_left.set_position(('outward', 0))
spine_left.set_linewidth(5)

spine_bottom = spines['bottom']
spine_bottom.set_visible(True)
fig

# %%
spine_left = spines['left']
spine_left.set_position(('outward', -50))
spine_left.set_linewidth(5)

spine_bottom = spines['bottom']
spine_bottom.set_visible(True)
fig

# %%
spine_left = spines['left']
spine_left.set_position(('outward', -100))
spine_left.set_linewidth(5)

spine_bottom = spines['bottom']
spine_bottom.set_visible(False)
fig

# %%
spine_left = spines['left']
spine_left.set_position(('outward', -200))
spine_left.set_linewidth(5)

spine_bottom = spines['bottom']
spine_bottom.set_visible(False)
fig

# %%
spine_left = spines['left']
spine_left.set_position(('outward', -200))
spine_left.set_linewidth(5)

spine_bottom = spines['bottom']
spine_bottom.set_position(('outward', 0))
fig

# %%
spine_left = spines['left']
spine_left.set_position(('outward', -200))
spine_left.set_linewidth(5)

spine_bottom = spines['bottom']
spine_bottom.set_position(('outward', 50))
fig

# %%
spine_left = spines['left']
spine_left.set_position(('outward', -200))
spine_left.set_linewidth(5)

spine_bottom = spines['bottom']
spine_bottom.set_position(('outward', -50))
fig

# %%
ax.xaxis.grid(True, which='major', linewidth=2, color='red', linestyle='--')  # True means 'turning on the gridlines'
ax.xaxis.set_ticks([.2, .4, .55, .93])
ax.xaxis.set_label_text('X Axis', family='Verdana', fontsize=15)

ax.set_ylabel('Y Axis', family='Calibri', fontsize=20)
ax.set_yticks([.1, .9])
ax.set_yticklabels(['point 1', 'point 9'], rotation=45)
fig

# %%
fig, ax = plt.subplots(nrows=1, ncols=1)

# %%
fig.set_facecolor('.9')
ax.set_facecolor('.7')

fig

# %%
spine_left = spines['left']
spine_left.set_position(('outward', -200))
spine_left.set_linewidth(5)

spine_bottom = spines['bottom']
spine_bottom.set_position(('outward', 0))

ax.xaxis.grid(True, which='major', linewidth=2, color='red', linestyle='--')
ax.xaxis.set_ticks([.2, .4, .55, .93])
ax.xaxis.set_label_text('X Axis', family='Verdana', fontsize=15)

ax.yaxis.grid(True, which='major', linewidth=2, color='blue', linestyle='--')
ax.yaxis.set_ticks([.2, .4, .55, .93])
ax.yaxis.set_label_text('Y Axis', family='Calibri', fontsize=15)

fig

# %%
fig, ax = plt.subplots(nrows=2, ncols=2)
fig.set_size_inches(14, 4)
print(type(ax))
print(ax)
print(ax[0])
print(ax[0][0])

fig.set_facecolor('.9')
ax[0][0].set_facecolor ('.7')
# Out:
# <class 'numpy.ndarray'>
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x7fbf55f469b0>
# ...
# AxesSubplot(0.125,0.536818;0.352273x0.343182)

# %%
fig, ax = plt.subplots(nrows=1, ncols=2)
fig.set_size_inches(14, 4)
print(type(ax))
print(ax)
print(ax[0])

fig.set_facecolor('.9')
ax[1].set_facecolor ('.7')
# Out:
# <class 'numpy.ndarray'>
# ...
# AxesSubplot(0.125,0.125;0.352273x0.755)

# %%
ax_children = ax[1].get_children()
ax_children
# Out:
# ...
#  Text(0.5, 1.0, ''),
#  Text(0.0, 1.0, ''),
#  Text(1.0, 1.0, ''),
# ...
